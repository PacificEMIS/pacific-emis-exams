# %%
###############################################################################
# This notebook provides some cleanup tools                                   #
# Tools include the following                                                 #
#   - Remove all files in a directory tree that is not an AllSchool           #
#   - Combined all schools in a directory into a AllSchools (when missing)    #
###############################################################################

# Core stuff
import os
from pathlib import Path
import re

# Data stuff
import pandas as pd # Data analysis
import xlrd # excel 
import pyodbc # SQL DB

# Initial setup
test = 'MISAT' # NMCT
country = 'RMI' # FSM
cwd = os.getcwd()

# %%
def load_excel_to_df(filename):
    """Loads an Excel filename to a Pandas DataFrame.

    Parameters
    ----------
    filename : str, required
        The filename of the excel file to load

    Raises
    ------
    NotImplementedError
        Could raise unknown error. Implement if it happens
    
    Returns
    -------
    DataFrame
    """
    file_path = Path(filename)
    file_extension = file_path.suffix.lower()[1:]

    if file_extension == 'xlsx':
        df = pd.read_excel(filename, index_col=None, header=0, engine='openpyxl')
    elif file_extension == 'xls':
        df = pd.read_excel(filename, index_col=None, header=0)
    elif file_extension == 'csv':
        df = pd.read_csv(filename, index_col=None, header=0)
    else:
        raise Exception("File not supported")

    return df

# %%
# Cleanup and only keep the AllSchools exams file
data_dir = 'data/'+country+'/'+test
path = os.path.join(cwd, data_dir)

p = re.compile('AllSchool', re.IGNORECASE)

for root, directories, files in os.walk(path, topdown=False):
    for name in files:
        if p.match(name):
            pass
            #print(os.path.join(root, name))
        else:            
            print('Deleting file: ', os.path.join(root, name))
            os.remove(os.path.join(root, name))
    #for name in directories:
    #    print(os.path.join(root, name))

# %%
# Combined all schools in a directory into a single AllSchools
data_dir = 'data/'+country+'/combine-from-schools'
path = os.path.join(cwd, data_dir)

df_student_results_list = []

for root, directories, files in os.walk(path, topdown=False):
    for name in files:
        filename = os.path.join(root, name)
        print('Loading into DataFrame:', filename)
        try:
            df_student_results_list.append(load_excel_to_df(filename))
        except Error as e:
            print('Problem loading:', filename)
            print('Error was', e)            

print('Completed loading excel files')

df_all_schools_student_resuls = pd.concat(df_student_results_list)
df_all_schools_student_resuls

# Write resulting AllSchool DataFrame into Excel
filename = os.path.join(data_dir, 'AllSchools_M06_2013-14_Results.xlsx')
with pd.ExcelWriter(filename) as writer:
    df_all_schools_student_resuls.to_excel(writer, index=False, sheet_name='Responses', engine='openpyxl')
    
print('Completed writing resulting AllSchool DataFrame to file')
# Out:
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Aerok A_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ailuk_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Airok M_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ajeltake Christian Academy_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ajeltake_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Arno_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Assumption_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Aur_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Bikarej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Buoj_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Carlos_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Delap SDA_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/DES_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebadon_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye Calvary_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye Christian_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye Public_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye SDA_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebon_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ejit_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Enejet_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Enewa_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Enniburr_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Gem Christian School_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Imiej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Imroj_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ine_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jabat_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jabnoden_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jabor_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jah_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jaluit_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jebro_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jebwan_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jeh_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jepal_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Kattiej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Kaven_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Kili_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lae_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Laura Public_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Laura SDA_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lib_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Likiep_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Loen_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Longar_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lukoj_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lukonwod_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mae_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Majken_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Majuro Baptist Christian Academy_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Majuro Coop_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Matolen_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejatto_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejel_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejit_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejurirok_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Melang_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mili_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Nallo_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Namdrik_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Namu_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Narmej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ollet_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Queen of Peace_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Rairok_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/RES_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Rita Christian_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Rongrong Christian Elementary_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/St. Joseph_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tarawa_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tinak_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tobal_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Toka_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tokewa_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tutu_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/UES_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ujae_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ulien_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Utrik_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Wodmeej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Woja A_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Woja M_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Wotje_M06_2013-14_Results.xls
# Completed loading excel files
# Completed writing resulting AllSchool DataFrame to file
