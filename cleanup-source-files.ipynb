# %%
###############################################################################
# This notebook provides some cleanup tools                                   #
# Tools include the following                                                 #
#   - Remove all files in a directory tree that is not an AllSchool           #
#   - Combined all schools in a directory into a AllSchools (when missing)    #
###############################################################################

# Core stuff
import os
from pathlib import Path
import re

# Data stuff
import pandas as pd # Data analysis
import xlrd # excel 
import pyodbc # SQL DB

# Initial setup
test = 'MISAT' # NMCT
country = 'RMI' # FSM
cwd = os.getcwd()

# %%
def load_excel_to_df(filename):
    """Loads an Excel filename to a Pandas DataFrame.

    Parameters
    ----------
    filename : str, required
        The filename of the excel file to load

    Raises
    ------
    NotImplementedError
        Could raise unknown error. Implement if it happens
    
    Returns
    -------
    DataFrame
    """
    file_path = Path(filename)
    file_extension = file_path.suffix.lower()[1:]

    if file_extension == 'xlsx':
        df = pd.read_excel(filename, index_col=None, header=0, engine='openpyxl')
    elif file_extension == 'xls':
        df = pd.read_excel(filename, index_col=None, header=0)
    elif file_extension == 'csv':
        df = pd.read_csv(filename, index_col=None, header=0)
    else:
        raise Exception("File not supported")

    return df

# %%
# %%time
# Cleanup and only keep the AllSchools exams file
data_dir = 'data/'+country+'/'+test
path = os.path.join(cwd, data_dir)

p = re.compile('AllSchool', re.IGNORECASE)

for root, directories, files in os.walk(path, topdown=False):
    for name in files:
        if p.match(name):
            pass
            #print(os.path.join(root, name))
        else:            
            print('Deleting file: ', os.path.join(root, name))
            os.remove(os.path.join(root, name))
    #for name in directories:
    #    print(os.path.join(root, name))

# %%
# After cleanup verify each directory has the AllSchools exams file
for root, directories, files in os.walk(path, topdown=False):
    for d in directories:
        if root[len(path):].count(os.sep) == 1:
            d_abs = os.path.join(root, d)
            print("Directory {}".format(d_abs))
            # Check all files
            files = os.listdir(d_abs)
            for filename in files:
                print("Contain file {}".format(filename))
# Out:
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/3GrEng2009
# Contain file AllSchools_A03_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/3GrKM2009
# Contain file AllSchools_B03_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/3GrMath2009
# Contain file AllSchools_M03_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/6GrEng2009
# Contain file AllSchools_A06_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/6GrKM2009
# Contain file AllSchools_B06_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/6GrMath2009
# Contain file AllSchools_M06_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2009/8GrHSET2009
# Contain file AllSchools_H08_2008-09_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/3GrEng2010
# Contain file AllSchools_A03_2009-10_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/3GrKM2010
# Contain file AllSchools_B03_2009-10_Results1.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/3GrMath
# Contain file AllSchools_M03_2009-10_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/6GrEng2010
# Contain file AllSchools_A06_2009-10_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/6GrKm2010
# Contain file AllSchools_B06_2009-10_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/6GrMath2010
# Contain file AllSchools_M06_2009-10_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2010/8GrHSET2010
# Contain file AllSchools_H08_2009-10_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/3GrEng2011
# Contain file AllSchools_A03_2010-11_Results1.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/3GrKM2011
# Contain file AllSchools_B03_2010-11_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/3GrMath2011
# Contain file AllSchools_M03_2010-11_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/6GrEng2011
# Contain file AllSchools_A06_2010-11_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/6GrKM2011
# Contain file AllSchools_B06_2010-11_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/6GrMath2011
# Contain file AllSchools_M06_2010-11_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2011/8GrHSET2011
# Contain file AllSchools_H08_2010-11_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/3GrEng2012
# Contain file AllSchools_A03_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/3GrKM2012
# Contain file AllSchools_B03_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/3GrMath2012
# Contain file AllSchools_M03_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/6GrEng2012
# Contain file AllSchools_A06_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/6GrKM2012
# Contain file AllSchools_B06_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/6GrMath2012
# Contain file AllSchools_M06_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2012/8GrHSET2012
# Contain file AllSchools_H08_2011-12_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr10Eng2013
# Contain file AllSchools_E10_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr10Math2013
# Contain file AllSchools_M10_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr12Eng2013
# Contain file AllSchools_E12_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr12Math2013
# Contain file AllSchools_A12_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr3Eng2013
# Contain file AllSchools_A03_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr3KM2013
# Contain file AllSchools_B03_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr3Math2013
# Contain file AllSchools_M03_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr6Eng2013
# Contain file AllSchools_A06_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr6KM2013
# Contain file AllSchools_B06_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr6Math2013
# Contain file AllSchools_M06_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2013/Gr8HSET2013
# Contain file AllSchools_H08_2012-13_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr10Eng2014
# Contain file AllSchools_E10_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr10Math2014
# Contain file AllSchools_M10_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr12Eng2014
# Contain file AllSchools_E12_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr12Math2014
# Contain file AllSchools_A12_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr3Eng2014
# Contain file AllSchools_A03_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr3KM2014
# Contain file AllSchools_B03_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr3Math2014
# Contain file AllSchools_M03_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr6Eng2014
# Contain file AllSchools_A06_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr6KM2014
# Contain file AllSchools_B06_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr6Math2014
# Contain file AllSchools_M06_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2014/Gr8HSET2014
# Contain file AllSchools_H08_2013-14_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr10Eng2015
# Contain file AllSchools_E10_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr10Math2015
# Contain file AllSchools_M10_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr12Eng2015
# Contain file AllSchools_E12_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr12Math2015
# Contain file AllSchools_B12_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr3Eng2015
# Contain file AllSchools_A03_2014-15_Results1.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr3KM2015
# Contain file AllSchools_B03_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr3math2015
# Contain file AllSchools_M03_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr6Eng2015
# Contain file AllSchools_A06_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr6KM2015
# Contain file AllSchools_B06_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr6Math2015
# Contain file AllSchools_M06_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2015/Gr8HSET2015
# Contain file AllSchools_H08_2014-15_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr10Eng2016
# Contain file AllSchools_E10_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr10Math2016
# Contain file AllSchools_M10_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr12Eng2016
# Contain file AllSchools_E12_2015-16_Results.xls.xlsx
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr12Math2016
# Contain file AllSchools_B12_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr3Eng2016
# Contain file AllSchools_A03_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr3KM2016
# Contain file AllSchools_B03_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr3Math2016
# Contain file AllSchools_M03_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr6Eng2016
# Contain file AllSchools_A06_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr6KM2016
# Contain file AllSchools_B06_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr6Math2016
# Contain file AllSchools_M06_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2016/Gr8HSET2016
# Contain file AllSchools_H08_2015-16_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr10Eng2017
# Contain file AllSchools_E10_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr10Math2017
# Contain file AllSchools_M10_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr12Eng2017
# Contain file AllSchools_E12_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr12Math2017
# Contain file AllSchools_B12_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr3Eng2017
# Contain file AllSchools_A03_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr3KM2017
# Contain file AllSchools_B03_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr3Math2017
# Contain file AllSchools_M03_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr6Eng2017
# Contain file AllSchools_A06_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr6KM2017
# Contain file AllSchools_B06_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr6Math2017
# Contain file AllSchools_M06_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2017/Gr8HSET2017
# Contain file AllSchools_H08_2016-17_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr10Eng2018
# Contain file AllSchools_E10_2017-18_Results (2).xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr10Math2018
# Contain file AllSchools_M10_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr12Eng2018
# Contain file AllSchools_E12_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr12Math2018
# Contain file AllSchools_B12_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr3Eng2018
# Contain file AllSchools_A03_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr3KM2018
# Contain file AllSchools_B03_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr3Math2018
# Contain file AllSchools_M03_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr6Eng2018
# Contain file AllSchools_A06_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr6KM2018
# Contain file AllSchools_B06_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2018/Gr6Math2018
# Contain file AllSchools_M06_2017-18_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr10Eng2019
# Contain file AllSchools_E10_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr10Math2019
# Contain file AllSchools_M10_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr12Eng2019
# Contain file AllSchools_E12_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr12Math2019
# Contain file AllSchools_B12_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr3Eng2019
# Contain file AllSchools_A03_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr3KM2019
# Contain file AllSchools_B03_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr3Math2019
# Contain file AllSchools_M03_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr6Eng2019
# Contain file AllSchools_A06_2018-19_Results REG.xls
# Contain file AllSchools_A06_2018-19_Results SPED.xlsx
# Contain file AllSchools_A06_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr6KM2019
# Contain file AllSchools_B06_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr6Math2019
# Contain file AllSchools_M06_2018-19_Results.xls
# Directory /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams/data/RMI/MISAT/MISAT 2019/Gr8HSET2019
# Contain file AllSchools_H08_2018-19_Results.xls

# %%
# Combined all schools in a directory into a single AllSchools
data_dir = 'data/'+country+'/combine-from-schools'
path = os.path.join(cwd, data_dir)

df_student_results_list = []

for root, directories, files in os.walk(path, topdown=False):
    for name in files:
        filename = os.path.join(root, name)
        print('Loading into DataFrame:', filename)
        try:
            df_student_results_list.append(load_excel_to_df(filename))
        except Error as e:
            print('Problem loading:', filename)
            print('Error was', e)            

print('Completed loading excel files')

df_all_schools_student_resuls = pd.concat(df_student_results_list)
df_all_schools_student_resuls

# Write resulting AllSchool DataFrame into Excel
filename = os.path.join(data_dir, 'AllSchools_M06_2013-14_Results.xlsx')
with pd.ExcelWriter(filename) as writer:
    df_all_schools_student_resuls.to_excel(writer, index=False, sheet_name='Responses', engine='openpyxl')
    
print('Completed writing resulting AllSchool DataFrame to file')
# Out:
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Aerok A_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ailuk_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Airok M_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ajeltake Christian Academy_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ajeltake_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Arno_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Assumption_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Aur_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Bikarej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Buoj_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Carlos_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Delap SDA_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/DES_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebadon_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye Calvary_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye Christian_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye Public_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebeye SDA_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ebon_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ejit_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Enejet_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Enewa_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Enniburr_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Gem Christian School_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Imiej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Imroj_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ine_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jabat_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jabnoden_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jabor_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jah_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jaluit_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jebro_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jebwan_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jeh_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Jepal_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Kattiej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Kaven_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Kili_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lae_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Laura Public_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Laura SDA_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lib_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Likiep_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Loen_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Longar_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lukoj_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Lukonwod_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mae_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Majken_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Majuro Baptist Christian Academy_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Majuro Coop_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Matolen_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejatto_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejel_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejit_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mejurirok_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Melang_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Mili_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Nallo_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Namdrik_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Namu_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Narmej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ollet_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Queen of Peace_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Rairok_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/RES_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Rita Christian_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Rongrong Christian Elementary_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/St. Joseph_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tarawa_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tinak_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tobal_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Toka_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tokewa_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Tutu_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/UES_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ujae_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Ulien_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Utrik_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Wodmeej_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Woja A_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Woja M_M06_2013-14_Results.xls
# Loading into DataFrame: /mnt/c/Users/Ghislain Hachey/Google Drive (ghachey@nuzusys.com)/Development/Pacific EMIS/repositories/pacific-emis-exams-data-jupyter-python/data/RMI/MISAT/combine-from-schools/Wotje_M06_2013-14_Results.xls
# Completed loading excel files
# Completed writing resulting AllSchool DataFrame to file
